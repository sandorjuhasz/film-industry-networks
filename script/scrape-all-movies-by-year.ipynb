# %% [markdown]
# ## scrape single pages from the Hungarian Film Archive
# http://mandarchiv.hu/tart/jatekfilm

# %%
from bs4 import BeautifulSoup as soup, Tag
from bs4 import BeautifulSoup
import requests
import pandas as pd
import random

import json

# %%
# 

USER_AGENTS = [
    # Chrome
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36',
    # Firefox
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:25.0) Gecko/20100101 Firefox/25.0',
    # Opera
    'Opera/9.80 (Windows NT 6.0) Presto/2.12.388 Version/12.14',
    # Safari
    'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25',
    # Internet Explorer
    'Mozilla/5.0 (compatible; MSIE 10.6; Windows NT 6.1; Trident/5.0; InfoPath.2; SLCC1; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 2.0.50727) 3gpp-gba UNTRUSTED/1.0',
]

def get_header(agents):
    return {'User-agent': random.choice(agents)}

# %%
url = 'http://mandarchiv.hu/tart/jatekfilm?action=search&title=&stab=&szereplo=&gyarto=&szinesseg=&gyartas_tol=2009&gyartas_ig=2009&tartalom=&dij='
response = requests.get(url, headers=get_header(USER_AGENTS))
soup = BeautifulSoup(response.content, "html.parser")

# %%
link = []

input_link = soup.findAll('a', {'class': 'title'})
for l in input_link:
    l_temp = l.get("href")
    l_temp = l_temp[-9:]
    link.append(l_temp)
    
#link = {'link' : pd.Series(link)}
#link_2009_2010 = pd.DataFrame(link)

# %%
data = {}

for id in list(link):
    url = 'http://mandarchiv.hu/tart/jatekfilm?name=jatekfilm&action=film&id=' + str(id) #target webpage
    response = requests.get(url, headers=get_header(USER_AGENTS))
    soup = BeautifulSoup(response.content, "html.parser")
    
    # necessary lists
    title = []
    year = []
    director = []
    cinematographer = []
    writer = []
    editor = []
    producer = []


    
    # title
    input_title = soup.find("div", {"class": "w_480"}).findNext('h2')
    for T in input_title:
        T_temp = input_title.text
        title.append(T_temp)
    
    # year
    input_year = soup.find('p', {'class': 'date'})
    for Y in input_year:
        Y_temp = input_year.text
        Y_temp = Y_temp[-5:]
        year.append(Y_temp)
    
    # director
    for d in soup.findAll(text='rendező / director:'):
        for item in d.parent.next_siblings:
            if isinstance(item, Tag):
                if 'class' in item.attrs and 'name' in item.attrs['class']:
                    break
                d_body = item.text
                director.append(d_body)
            
    # writer
    for w in soup.findAll(text='forgatókönyvíró / writer (screenplay):'):
        for item in w.parent.next_siblings:
            if isinstance(item, Tag):
                if 'class' in item.attrs and 'name' in item.attrs['class']:
                    break
                w_body = item.text
                writer.append(w_body)
    
    # cinematographer
    for c in soup.findAll(text='operatőr / cinematographer:'):
        for item in c.parent.next_siblings:
            if isinstance(item, Tag):
                if 'class' in item.attrs and 'name' in item.attrs['class']:
                    break
                c_body = item.text
                cinematographer.append(c_body)
    
    # editor
    for e in soup.findAll(text='vágó / editor:'):
        for item in e.parent.next_siblings:
            if isinstance(item, Tag):
                if 'class' in item.attrs and 'name' in item.attrs['class']:
                    break
                e_body = item.text
                editor.append(e_body)
    
    # producer
    for t in soup.findAll(text='producer / producer:'):
        for item in t.parent.next_siblings:
            if isinstance(item, Tag):
                if 'class' in item.attrs and 'name' in item.attrs['class']:
                    break
                p_body = item.text
                producer.append(p_body)
    
    data[id] = []
    data[id].append({
            'title' : title,
            'year' : year,
            'director' : director,
            'writer' : writer,
            'cinematographer' : cinematographer,
            'editor' : editor,
            'producer' : producer
    })

# %%
with open('../data/films_2009.txt', 'w') as outfile:
    json.dump(data, outfile)

# %%
import json

with open('../data/films_2009.txt') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'290026648': [{'title': ["Father's Acre"],
#    'year': [' 2009'],
#    'director': ['Nagy, Viktor Oszkár'],
#    'writer': ['Nagy, Viktor Oszkár'],
#    'cinematographer': ['Dobos, Tamás'],
#    'editor': ['Nagy, Viktor Oszkár'],
#    'producer': ['Miskolczi, Péter', 'Bosnyák, Miklós']}],
#  '290027023': [{'title': ['Intimate Headshot'],
#    'year': [' 2009'],
#    'director': ['Szajki Péter'],
#    'writer': ['Szajki Péter'],
#    'cinematographer': ['Petrik András'],
#    'editor': ['Papp Szilvia'],
#    'producer': ['Szűcs Dóra',
#     'Rajna, Gábor',
#     'Reich, Péter',
#     'Sipos, Gábor',
#     'Angelusz, Iván']}],
#  '290027054': [{'title': ['1'],
#    'year': [' 2009'],
#    'director': ['Pater Sparrow,  '],
#    'writer': ['Pater Sparrow,  ', 'Góczán, Judit'],
#    'cinematographer': ['Tóth, Widamon Máté'],
#    'editor': ['Kiss, Wanda'],
#    'producer': ['Kamondi, Zoltán']}],
#  '290027491': [{'title': ['Dream.net'],
#    'year': [' 2009'],
#    'director': ['N. Forgács Gábor'],
#    'writer': ['N. Forgács Gábor', 'Steiner, Kristóf'],
#    'cinematographer': ['Tóth, Zsolt (I)'],
#    'editor': ['Vásárhelyi, Tamás', 'N. Forgács Gábor', 'Steiner, Kristóf'],
#    'producer': ['Sallay, Edina', 'Cirkó, József']}],
#  '290027641': [{'title': ['Paper Planes'],
#    'year': [' 2009'],
#    'director': ['Szabó, Simon'],
#    'writer': ['Szabó, Simon'],
#    'cinematographer': ['Czomba, Albert'],
#    'editor': ['Czomba, Albert'],
#    'producer': ['Csáky, Attila', 'AfterjkA']}],
#  '290028043': [{'title': ['The Days of Desire'],
#    'year': [' 2009'],
#    'director': ['Pacskovszky, József'],
#    'writer': ['Pacskovszky, József'],
#    'cinematographer': ['Kardos, Sándor (I)'],
#    'editor': ['Koncz, Gabriella'],
#    'producer': ['Hábermann, Jenő']}],
#  '290028194': [{'title': ['Camembert Rose'],
#    'year': [' 2009'],
#    'director': ['Tóth, Barnabás'],
#    'writer': ['Tóth, Barnabás', 'Hamvas, Dániel', 'Rizzo, Frank'],
#    'cinematographer': ['Seres, Bálint', 'Niczyporuk, Przemyslaw'],
#    'editor': ['Lemhényi, Réka'],
#    'producer': ['Hábermann, Jenő']}],
#  '290028475': [{'title': ['The Last Report On Anna'],
#    'year': [' 2009'],
#    'director': ['Mészáros, Márta'],
#    'writer': ['Mészáros, Márta', 'Pataki, Éva'],
#    'cinematographer': ['Novák, Emil'],
#    'editor': ['Kajdácsi, Brigitta', 'Csákány, Zsuzsa'],
#    'producer': ['Sándor, Pál']}],
#  '290028646': [{'title': ['Poligamy'],
#    'year': [' 2009'],
#    'director': ['Orosz Dénes'],
#    'writer': ['Orosz Dénes'],
#    'cinematographer': ['Fillenz, Ádám'],
#    'editor': ['Kovács Zoltán (II.)'],
#    'producer': ['Herendi Gábor']}],
#  '290028666': [{'title': ['Lull'],
#    'year': [' 2009'],
#    'director': ['Sas, Tamás'],
#    'writer': ['Csikesz, Judit'],
#    'cinematographer': ['Sas, Tamás'],
#    'editor': ['Major Klára'],
#    'producer': ['Sas, Tamás', 'Faragó Attila']}],
#  '290028670': [{'title': ['Question in Details'],
#    'year': [' 2009'],
#    'director': ['Dyga, Zsombor'],
#    'writer': ['Dyga, Zsombor'],
#    'cinematographer': ['Marosi, Gábor'],
#    'editor': ['Czakó, Judit'],
#    'producer': ['Major, István']}],
#  '290028805': [{'title': ['Prank'],
#    'year': [' 2009'],
#    'director': ['Gárdos, Péter'],
#    'writer': ['Bíró, Zsuzsa (I)'],
#    'cinematographer': ['Seregi László ifj.'],
#    'editor': ['Miklós, Mari'],
#    'producer': ['Szekeres, Dénes']}],
#  '290028906': [{'title': ['Lost Times'],
#    'year': [' 2009'],
#    'director': ['Mátyássy, Áron'],
#    'writer': ['Mátyássy, Áron'],
#    'cinematographer': ['Herbai, Máté'],
#    'editor': ['Kovács Zoltán (II.)', 'Féjja, Gyöngyi'],
#    'producer': ['Bodzsár, István']}],
#  '290029019': [{'title': ['I Am Not Your Friend'],
#    'year': [' 2009'],
#    'director': ['Pálfi, György'],
#    'writer': [],
#    'cinematographer': ['Dala, István'],
#    'editor': [],
#    'producer': ['Angelusz, Iván',
#     'Pálfi, György',
#     'Miskolczi, Péter',
#     'Váradi, Gábor (I)']}],
#  '290029039': [{'title': ['Out/In Tawaret'],
#    'year': [' 2009'],
#    'director': ['Molnár, György'],
#    'writer': ['Molnár, György'],
#    'cinematographer': ['Csukás, Sándor'],
#    'editor': ['Király Ferenc (II.)'],
#    'producer': ['Kántor, László']}],
#  '290029069': [{'title': ['Chirribirri'],
#    'year': [' 2009'],
#    'director': ['Rózsa, János'],
#    'writer': ['Vészits, Andrea'],
#    'cinematographer': ['Reich, Dániel',
#     'Major, Attila (II.)',
#     'Lenhardt, László',
#     'Lőrincz, József',
#     'Klöpfler, Tibor',
#     'Kovács Zoltán (III.)',
#     'Bornyi, Gábor',
#     'Vass, Gergely',
#     'Dobóczy, Balázs'],
#    'editor': [],
#    'producer': ['Vészits, Andrea', 'Rózsa, János', 'Temple, Réka']}],
#  '290029091': [{'title': ['Made in Hungaria'],
#    'year': [' 2009'],
#    'director': ['Fonyó, Gergely'],
#    'writer': [],
#    'cinematographer': ['Csukás, Sándor'],
#    'editor': ['Csillag, Mano'],
#    'producer': ['Cirkó, József', 'Neményi, Ádám']}],
#  '290029133': [{'title': ['Dad, Actually'],
#    'year': [' 2009'],
#    'director': ['Kaszás, Géza'],
#    'writer': ['Novák, Emil', 'Péterfy Gergely', 'Kaszás, Géza'],
#    'cinematographer': ['Csukás, Sándor'],
#    'editor': ['Major Klára'],
#    'producer': ['Kaszás, Géza', 'Poós, András']}],
#  '290029358': [{'title': ['In the Land of Wonders'],
#    'year': [' 2009'],
#    'director': ['Šorak, Dejan'],
#    'writer': ['Šorak, Dejan'],
#    'cinematographer': ['Vrdoljak, Vjekoslav'],
#    'editor': ['Segaric, Veljko'],
#    'producer': ['Szekeres, Dénes', 'Maloča, Ivan']}],
#  '290030219': [{'title': ['The Valley'],
#    'year': [' 2009'],
#    'director': ['Győrik, Mihály'],
#    'writer': [],
#    'cinematographer': [],
#    'editor': [],
#    'producer': ['Sipos, Áron']}],
#  '290030360': [{'title': ['Solemn Promise '],
#    'year': [' 2009'],
#    'director': ['Karanović, Srđan'],
#    'writer': [],
#    'cinematographer': [],
#    'editor': [],
#    'producer': []}],
#  '290030388': [{'title': ['My Husband’s Woman'],
#    'year': [' 2009'],
#    'director': ['Vojnár, Ivan'],
#    'writer': [],
#    'cinematographer': [],
#    'editor': [],
#    'producer': []}]}
